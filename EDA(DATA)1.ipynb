# %% [markdown]
# <a href="https://colab.research.google.com/github/tata-lakshman/Explanatory-Data-Analysis_3/blob/main/EDA(DATA)1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Loading the DataSet

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8a6c8bdf-31a9-4999-b5b2-f0b726b42713" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8a6c8bdf-31a9-4999-b5b2-f0b726b42713">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('data.csv', encoding='latin1')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# #Accessing First 5 Row's

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# #Accessing Last 5 Row's

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/2011 12:50       0.85     12680.0  France
# 541905  12/9/2011 12:50       2.10     12680.0  France
# 541906  12/9/2011 12:50       4.15     12680.0  France
# 541907  12/9/2011 12:50       4.15     12680.0  France
# 541908  12/9/2011 12:50       4.95     12680.0  France

# %% [markdown]
# #Number of Row's and Colums

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# #Displaying Total No of colums in DataSet

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %% [markdown]
# #Getting All Colums 1 by 1

# %%
for columns in df.columns:
  print(columns)
# Out:
# InvoiceNo
# StockCode
# Description
# Quantity
# InvoiceDate
# UnitPrice
# CustomerID
# Country

# %% [markdown]
# #Renaming Colums

# %%
d={
    'InvoiceNo':'invoice_no',
    'StockCode':'stock_code',
    'Description':'description',
    'Quantity':'quantity',
    'InvoiceDate':'invoice_date',
    'UnitPrice':'unit_price',
    'CustomerID':'customer_id',
    'Country':'country'
}

# %%
d
# Out:
# {'InvoiceNo': 'invoice_no',
#  'StockCode': 'stock_code',
#  'Description': 'description',
#  'Quantity': 'quantity',
#  'InvoiceDate': 'invoice_date',
#  'UnitPrice': 'unit_price',
#  'CustomerID': 'customer_id',
#  'Country': 'country'}

# %%
df.rename(columns=d,inplace=True)

# %% [markdown]
# #After changing column names checking new column names

# %%
df.columns
# Out:
# Index(['invoice_no', 'stock_code', 'description', 'quantity', 'invoice_date',
#        'unit_price', 'customer_id', 'country'],
#       dtype='object')

# %%
for i in df.columns:
  print(i)
# Out:
# invoice_no
# stock_code
# description
# quantity
# invoice_date
# unit_price
# customer_id
# country

# %% [markdown]
# #Cheching First 5 rows

# %%
df.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365      71053                  WHITE METAL LANTERN         6
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#      invoice_date  unit_price  customer_id         country
# 0  12/1/2010 8:26        2.55      17850.0  United Kingdom
# 1  12/1/2010 8:26        3.39      17850.0  United Kingdom
# 2  12/1/2010 8:26        2.75      17850.0  United Kingdom
# 3  12/1/2010 8:26        3.39      17850.0  United Kingdom
# 4  12/1/2010 8:26        3.39      17850.0  United Kingdom

# %% [markdown]
# #Data Cleaning
# #Check column datatype

# %%
df.dtypes
# Out:
# invoice_no       object
# stock_code       object
# description      object
# quantity          int64
# invoice_date     object
# unit_price      float64
# customer_id     float64
# country          object
# dtype: object

# %% [markdown]
# #DataFrame Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_no    541909 non-null  object
#  1   stock_code    541909 non-null  object
#  2   description   540455 non-null  object
#  3   quantity      541909 non-null  int64
#  4   invoice_date  541909 non-null  object
#  5   unit_price    541909 non-null  float64
#  6   customer_id   406829 non-null  float64
#  7   country       541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# #checking missing values for each Column

# %%
df.isnull()
# Out:
#         invoice_no  stock_code  description  quantity  invoice_date  \
# 0            False       False        False     False         False
# 1            False       False        False     False         False
# 2            False       False        False     False         False
# 3            False       False        False     False         False
# 4            False       False        False     False         False
# ...            ...         ...          ...       ...           ...
# 541904       False       False        False     False         False
# 541905       False       False        False     False         False
# 541906       False       False        False     False         False
# 541907       False       False        False     False         False
# 541908       False       False        False     False         False
#
#         unit_price  customer_id  country
# 0            False        False    False
# 1            False        False    False
# ...

# %% [markdown]
# #Checking Missing values count for each column

# %%
df.isnull().sum()
# Out:
# invoice_no           0
# stock_code           0
# description       1454
# quantity             0
# invoice_date         0
# unit_price           0
# customer_id     135080
# country              0
# dtype: int64

# %% [markdown]
# #Checking No of colums

# %%
len(df.columns)
# Out:
# 8

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# #Checking missing values count on each column and applying sorting

# %%
df.isnull().sum().sort_values()
# Out:
# invoice_no           0
# stock_code           0
# quantity             0
# invoice_date         0
# country              0
# unit_price           0
# description       1454
# customer_id     135080
# dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# customer_id     135080
# description       1454
# stock_code           0
# invoice_no           0
# quantity             0
# invoice_date         0
# unit_price           0
# country              0
# dtype: int64

# %% [markdown]
# #Checking Type of invoice_date column

# %%
df.dtypes
# Out:
# invoice_no       object
# stock_code       object
# description      object
# quantity          int64
# invoice_date     object
# unit_price      float64
# customer_id     float64
# country          object
# dtype: object

# %%
df.head(2)
# Out:
#   invoice_no stock_code                         description  quantity  \
# 0     536365     85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365      71053                 WHITE METAL LANTERN         6
#
#      invoice_date  unit_price  customer_id         country
# 0  12/1/2010 8:26        2.55      17850.0  United Kingdom
# 1  12/1/2010 8:26        3.39      17850.0  United Kingdom

# %% [markdown]
# #Converting invoice_date datatype into datatime data type

# %%
df['invoice_date']=pd.to_datetime(df['invoice_date'],format='%m/%d/%Y %H:%M')

# %% [markdown]
# #Check type of invoice_date

# %%
df.dtypes
# Out:
# invoice_no              object
# stock_code              object
# description             object
# quantity                 int64
# invoice_date    datetime64[ns]
# unit_price             float64
# customer_id            float64
# country                 object
# dtype: object

# %%
df.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365      71053                  WHITE METAL LANTERN         6
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#          invoice_date  unit_price  customer_id         country
# 0 2010-12-01 08:26:00        2.55      17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75      17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39      17850.0  United Kingdom

# %% [markdown]
# #Let us check description column

# %%
df.description
# Out:
# 0          WHITE HANGING HEART T-LIGHT HOLDER
# 1                         WHITE METAL LANTERN
# 2              CREAM CUPID HEARTS COAT HANGER
# 3         KNITTED UNION FLAG HOT WATER BOTTLE
# 4              RED WOOLLY HOTTIE WHITE HEART.
#                          ...
# 541904            PACK OF 20 SPACEBOY NAPKINS
# 541905           CHILDREN'S APRON DOLLY GIRL
# 541906          CHILDRENS CUTLERY DOLLY GIRL
# 541907        CHILDRENS CUTLERY CIRCUS PARADE
# 541908          BAKING SET 9 PIECE RETROSPOT
# Name: description, Length: 541909, dtype: object

# %% [markdown]
# #Converting description column into lowercase

# %%
df.description.str.lower()
# Out:
# 0          white hanging heart t-light holder
# 1                         white metal lantern
# 2              cream cupid hearts coat hanger
# 3         knitted union flag hot water bottle
# 4              red woolly hottie white heart.
#                          ...
# 541904            pack of 20 spaceboy napkins
# 541905           children's apron dolly girl
# 541906          childrens cutlery dolly girl
# 541907        childrens cutlery circus parade
# 541908          baking set 9 piece retrospot
# Name: description, Length: 541909, dtype: object

# %%
df.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365      71053                  WHITE METAL LANTERN         6
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#          invoice_date  unit_price  customer_id         country
# 0 2010-12-01 08:26:00        2.55      17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75      17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39      17850.0  United Kingdom

# %% [markdown]
# #Changing it in the original dataset

# %%
df['description']=df.description.str.lower()

# %%
df.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   white hanging heart t-light holder         6
# 1     536365      71053                  white metal lantern         6
# 2     536365     84406B       cream cupid hearts coat hanger         8
# 3     536365     84029G  knitted union flag hot water bottle         6
# 4     536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  customer_id         country
# 0 2010-12-01 08:26:00        2.55      17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75      17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39      17850.0  United Kingdom

# %% [markdown]
# #Missing values

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# customer_id     135080
# description       1454
# stock_code           0
# invoice_no           0
# quantity             0
# invoice_date         0
# unit_price           0
# country              0
# dtype: int64

# %% [markdown]
# #Dropping Missing Values

# %%
df_new=df.dropna()

# %%
df_new.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   white hanging heart t-light holder         6
# 1     536365      71053                  white metal lantern         6
# 2     536365     84406B       cream cupid hearts coat hanger         8
# 3     536365     84029G  knitted union flag hot water bottle         6
# 4     536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  customer_id         country
# 0 2010-12-01 08:26:00        2.55      17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75      17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39      17850.0  United Kingdom

# %% [markdown]
# #After Dropping missing values then check missing values for each column

# %%
df_new.isnull().sum().sort_values(ascending=False)
# Out:
# invoice_no      0
# stock_code      0
# description     0
# quantity        0
# invoice_date    0
# unit_price      0
# customer_id     0
# country         0
# dtype: int64

# %% [markdown]
# #DataFrame Information

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_no    406829 non-null  object
#  1   stock_code    406829 non-null  object
#  2   description   406829 non-null  object
#  3   quantity      406829 non-null  int64
#  4   invoice_date  406829 non-null  datetime64[ns]
#  5   unit_price    406829 non-null  float64
#  6   customer_id   406829 non-null  float64
#  7   country       406829 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.9+ MB

# %%
df_new.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   white hanging heart t-light holder         6
# 1     536365      71053                  white metal lantern         6
# 2     536365     84406B       cream cupid hearts coat hanger         8
# 3     536365     84029G  knitted union flag hot water bottle         6
# 4     536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  customer_id         country
# 0 2010-12-01 08:26:00        2.55      17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75      17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39      17850.0  United Kingdom

# %% [markdown]
# #checking type of customer_id

# %%
df_new.dtypes
# Out:
# invoice_no              object
# stock_code              object
# description             object
# quantity                 int64
# invoice_date    datetime64[ns]
# unit_price             float64
# customer_id            float64
# country                 object
# dtype: object

# %%
df_new['customer_id']
# Out:
# 0         17850.0
# 1         17850.0
# 2         17850.0
# 3         17850.0
# 4         17850.0
#            ...
# 541904    12680.0
# 541905    12680.0
# 541906    12680.0
# 541907    12680.0
# 541908    12680.0
# Name: customer_id, Length: 406829, dtype: float64

# %% [markdown]
# #Converting customer_id into float64 into int64

# %%
df_new['customer_id']=df_new['customer_id'].astype('int64')
# Out:
# /tmp/ipython-input-3577090103.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['customer_id']=df_new['customer_id'].astype('int64')

# %% [markdown]
# #Accessing First 5 rows

# %%
df_new.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   white hanging heart t-light holder         6
# 1     536365      71053                  white metal lantern         6
# 2     536365     84406B       cream cupid hearts coat hanger         8
# 3     536365     84029G  knitted union flag hot water bottle         6
# 4     536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  customer_id         country
# 0 2010-12-01 08:26:00        2.55        17850  United Kingdom
# 1 2010-12-01 08:26:00        3.39        17850  United Kingdom
# 2 2010-12-01 08:26:00        2.75        17850  United Kingdom
# 3 2010-12-01 08:26:00        3.39        17850  United Kingdom
# 4 2010-12-01 08:26:00        3.39        17850  United Kingdom

# %% [markdown]
# #New DataFrame information

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_no    406829 non-null  object
#  1   stock_code    406829 non-null  object
#  2   description   406829 non-null  object
#  3   quantity      406829 non-null  int64
#  4   invoice_date  406829 non-null  datetime64[ns]
#  5   unit_price    406829 non-null  float64
#  6   customer_id   406829 non-null  int64
#  7   country       406829 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(4)
# memory usage: 27.9+ MB

# %% [markdown]
# #DataFrame descreption

# %%
df_new.describe()
# Out:
#             quantity                   invoice_date     unit_price  \
# count  406829.000000                         406829  406829.000000
# mean       12.061303  2011-07-10 16:30:57.879207424       3.460471
# min    -80995.000000            2010-12-01 08:26:00       0.000000
# 25%         2.000000            2011-04-06 15:02:00       1.250000
# 50%         5.000000            2011-07-31 11:48:00       1.950000
# 75%        12.000000            2011-10-20 13:06:00       3.750000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       248.693370                            NaN      69.315162
#
#          customer_id
# count  406829.000000
# mean    15287.690570
# min     12346.000000
# 25%     13953.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000
# std      1713.600303

# %% [markdown]
# #Rounding the values in DataFrame

# %%
df_new.describe().round(2)
# Out:
#         quantity                   invoice_date  unit_price  customer_id
# count  406829.00                         406829   406829.00    406829.00
# mean       12.06  2011-07-10 16:30:57.879207424        3.46     15287.69
# min    -80995.00            2010-12-01 08:26:00        0.00     12346.00
# 25%         2.00            2011-04-06 15:02:00        1.25     13953.00
# 50%         5.00            2011-07-31 11:48:00        1.95     15152.00
# 75%        12.00            2011-10-20 13:06:00        3.75     16791.00
# max     80995.00            2011-12-09 12:50:00    38970.00     18287.00
# std       248.69                            NaN       69.32      1713.60

# %% [markdown]
# #Let us do some Analysis
# #Conclusion:quantity column has some -ve values
# #So,we need to remove/delete -ve values
# #Example to delete -ve values from list object

# %%
values=[1,2,3,-4,-5,6,7,-9]
for value in values:
    print(value)
print()
for value in values:
  if value>0:
    print(value)
# Out:
# 1
# 2
# 3
# -4
# -5
# 6
# 7
# -9
#
# 1
# 2
# 3
# 6
# 7

# %% [markdown]
# #Removing -ve values from quantity data

# %%
df_new.quantity>0
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 541904    True
# 541905    True
# 541906    True
# 541907    True
# 541908    True
# Name: quantity, Length: 406829, dtype: bool

# %%
con=df_new.quantity>0
df_new=df_new[con]
df_new.describe().round(2)
# Out:
#         quantity                   invoice_date  unit_price  customer_id
# count  397924.00                         397924   397924.00    397924.00
# mean       13.02  2011-07-10 23:43:36.912475648        3.12     15294.32
# min         1.00            2010-12-01 08:26:00        0.00     12346.00
# 25%         2.00            2011-04-07 11:12:00        1.25     13969.00
# 50%         6.00            2011-07-31 14:39:00        1.95     15159.00
# 75%        12.00            2011-10-20 14:33:00        3.75     16795.00
# max     80995.00            2011-12-09 12:50:00     8142.75     18287.00
# std       180.42                            NaN       22.10      1713.17

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_no    541909 non-null  object
#  1   stock_code    541909 non-null  object
#  2   description   540455 non-null  object
#  3   quantity      541909 non-null  int64
#  4   invoice_date  541909 non-null  datetime64[ns]
#  5   unit_price    541909 non-null  float64
#  6   customer_id   406829 non-null  float64
#  7   country       541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# #Access InitialData

# %%
df_new.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   white hanging heart t-light holder         6
# 1     536365      71053                  white metal lantern         6
# 2     536365     84406B       cream cupid hearts coat hanger         8
# 3     536365     84029G  knitted union flag hot water bottle         6
# 4     536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  customer_id         country
# 0 2010-12-01 08:26:00        2.55        17850  United Kingdom
# 1 2010-12-01 08:26:00        3.39        17850  United Kingdom
# 2 2010-12-01 08:26:00        2.75        17850  United Kingdom
# 3 2010-12-01 08:26:00        3.39        17850  United Kingdom
# 4 2010-12-01 08:26:00        3.39        17850  United Kingdom

# %% [markdown]
# #Checking total no rows and colums

# %%
df_new.shape
# Out:
# (397924, 8)

# %% [markdown]
# #Adding the column amount_spent

# %%
df_new['amount_spent']=df_new['quantity']*df_new['unit_price']

# %%
df_new.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   white hanging heart t-light holder         6
# 1     536365      71053                  white metal lantern         6
# 2     536365     84406B       cream cupid hearts coat hanger         8
# 3     536365     84029G  knitted union flag hot water bottle         6
# 4     536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  customer_id         country  amount_spent
# 0 2010-12-01 08:26:00        2.55        17850  United Kingdom         15.30
# 1 2010-12-01 08:26:00        3.39        17850  United Kingdom         20.34
# 2 2010-12-01 08:26:00        2.75        17850  United Kingdom         22.00
# 3 2010-12-01 08:26:00        3.39        17850  United Kingdom         20.34
# 4 2010-12-01 08:26:00        3.39        17850  United Kingdom         20.34

# %% [markdown]
# #lets read the column names from the dataframe

# %%
for i in df_new.columns:
  print(i)
# Out:
# invoice_no
# stock_code
# description
# quantity
# invoice_date
# unit_price
# customer_id
# country
# amount_spent

# %% [markdown]
# #Rearranging Colums for more Readability

# %%
col_order=['invoice_no','invoice_date','stock_code','description','quantity','unit_price','amount_spent','customer_id','country']

# %%
df_new=df_new[col_order]

# %% [markdown]
# #Access new column order

# %%
df_new.head()
# Out:
#   invoice_no        invoice_date stock_code  \
# 0     536365 2010-12-01 08:26:00     85123A
# 1     536365 2010-12-01 08:26:00      71053
# 2     536365 2010-12-01 08:26:00     84406B
# 3     536365 2010-12-01 08:26:00     84029G
# 4     536365 2010-12-01 08:26:00     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    customer_id         country
# 0        17850  United Kingdom
# 1        17850  United Kingdom
# 2        17850  United Kingdom
# 3        17850  United Kingdom
# 4        17850  United Kingdom

# %% [markdown]
# #Number of rows and colums

# %%
df_new.shape
# Out:
# (397924, 9)

# %% [markdown]
# #Let us do Analysis on invoice_date column
# #Accessing invoice_date column
# #Method-1 to access column

# %%
df_new['invoice_date']
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: invoice_date, Length: 397924, dtype: datetime64[ns]

# %% [markdown]
# #Method-2

# %%
df_new.invoice_date
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: invoice_date, Length: 397924, dtype: datetime64[ns]

# %% [markdown]
# #Accessing year value from invoice_date

# %%
df_new['invoice_date'].dt.year
# Out:
# 0         2010
# 1         2010
# 2         2010
# 3         2010
# 4         2010
#           ...
# 541904    2011
# 541905    2011
# 541906    2011
# 541907    2011
# 541908    2011
# Name: invoice_date, Length: 397924, dtype: int32

# %% [markdown]
# #Accesing month value from invoice_date

# %%
df_new.invoice_date.dt.month
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 541904    12
# 541905    12
# 541906    12
# 541907    12
# 541908    12
# Name: invoice_date, Length: 397924, dtype: int32

# %% [markdown]
# #Access initial data

# %%
df_new.head()
# Out:
#   invoice_no        invoice_date stock_code  \
# 0     536365 2010-12-01 08:26:00     85123A
# 1     536365 2010-12-01 08:26:00      71053
# 2     536365 2010-12-01 08:26:00     84406B
# 3     536365 2010-12-01 08:26:00     84029G
# 4     536365 2010-12-01 08:26:00     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    customer_id         country
# 0        17850  United Kingdom
# 1        17850  United Kingdom
# 2        17850  United Kingdom
# 3        17850  United Kingdom
# 4        17850  United Kingdom

# %% [markdown]
# #Lets insert year column in 2 position

# %%
c1='year'
df_new.insert(loc=2,column=c1,value=df_new['invoice_date'].dt.year)

# %%
df_new.head()
# Out:
#   invoice_no        invoice_date  year stock_code  \
# 0     536365 2010-12-01 08:26:00  2010     85123A
# 1     536365 2010-12-01 08:26:00  2010      71053
# 2     536365 2010-12-01 08:26:00  2010     84406B
# 3     536365 2010-12-01 08:26:00  2010     84029G
# 4     536365 2010-12-01 08:26:00  2010     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    customer_id         country
# 0        17850  United Kingdom
# 1        17850  United Kingdom
# 2        17850  United Kingdom
# 3        17850  United Kingdom
# 4        17850  United Kingdom

# %% [markdown]
# #lets insert month column in 3 position

# %%
c2='month'
df_new.insert(loc=3,column=c2,value=df_new['invoice_date'].dt.month)

# %%
df_new.head()
# Out:
#   invoice_no        invoice_date  year  month stock_code  \
# 0     536365 2010-12-01 08:26:00  2010     12     85123A
# 1     536365 2010-12-01 08:26:00  2010     12      71053
# 2     536365 2010-12-01 08:26:00  2010     12     84406B
# 3     536365 2010-12-01 08:26:00  2010     12     84029G
# 4     536365 2010-12-01 08:26:00  2010     12     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    customer_id         country
# 0        17850  United Kingdom
# 1        17850  United Kingdom
# 2        17850  United Kingdom
# 3        17850  United Kingdom
# ...

# %% [markdown]
# #We can get day of week

# %%
df_new.invoice_date.dt.dayofweek
# Out:
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2
#          ..
# 541904    4
# 541905    4
# 541906    4
# 541907    4
# 541908    4
# Name: invoice_date, Length: 397924, dtype: int32

# %% [markdown]
# #In pandas day format starts from 0 to 6
# Monday=0,Tuesday=1....Sunday=6
# #Apply +1 to make Monday=1...until sunday=7

# %%
c3='day'
v1=(df_new.invoice_date.dt.dayofweek)+1
df_new.insert(loc=4,column=c3,value=v1)

# %%
df_new.head()
# Out:
#   invoice_no        invoice_date  year  month  day stock_code  \
# 0     536365 2010-12-01 08:26:00  2010     12    3     85123A
# 1     536365 2010-12-01 08:26:00  2010     12    3      71053
# 2     536365 2010-12-01 08:26:00  2010     12    3     84406B
# 3     536365 2010-12-01 08:26:00  2010     12    3     84029G
# 4     536365 2010-12-01 08:26:00  2010     12    3     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    customer_id         country
# 0        17850  United Kingdom
# 1        17850  United Kingdom
# 2        17850  United Kingdom
# ...

# %%
len(df_new.columns)
# Out:
# 12

# %% [markdown]
# #Adding hours column to existing dataframe

# %%
df_new.invoice_date
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: invoice_date, Length: 397924, dtype: datetime64[ns]

# %%
df_new.invoice_date.dt.hour
# Out:
# 0          8
# 1          8
# 2          8
# 3          8
# 4          8
#           ..
# 541904    12
# 541905    12
# 541906    12
# 541907    12
# 541908    12
# Name: invoice_date, Length: 397924, dtype: int32

# %%
c4='hours'
v2=df_new.invoice_date.dt.hour
df_new.insert(loc=5,column=c4,value=v2)

# %%
df_new.head()
# Out:
#   invoice_no        invoice_date  year  month  day  hours stock_code  \
# 0     536365 2010-12-01 08:26:00  2010     12    3      8     85123A
# 1     536365 2010-12-01 08:26:00  2010     12    3      8      71053
# 2     536365 2010-12-01 08:26:00  2010     12    3      8     84406B
# 3     536365 2010-12-01 08:26:00  2010     12    3      8     84029G
# 4     536365 2010-12-01 08:26:00  2010     12    3      8     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    customer_id         country
# 0        17850  United Kingdom
# 1        17850  United Kingdom
# ...

# %% [markdown]
# #Lets display all colums one by one

# %%
for i in df_new.columns:
  print(i)
# Out:
# invoice_no
# invoice_date
# year
# month
# day
# hours
# stock_code
# description
# quantity
# unit_price
# amount_spent
# customer_id
# country

# %% [markdown]
# #Exploratory Data Analysis (EDA)

# %%
df_new.groupby(['customer_id']).count()
# Out:
#              invoice_no  invoice_date  year  month  day  hours  stock_code  \
# customer_id
# 12346                 1             1     1      1    1      1           1
# 12347               182           182   182    182  182    182         182
# 12348                31            31    31     31   31     31          31
# 12349                73            73    73     73   73     73          73
# 12350                17            17    17     17   17     17          17
# ...                 ...           ...   ...    ...  ...    ...         ...
# 18280                10            10    10     10   10     10          10
# 18281                 7             7     7      7    7      7           7
# 18282                12            12    12     12   12     12          12
# 18283               756           756   756    756  756    756         756
# 18287                70            70    70     70   70     70          70
#
# ...

# %%
df_new.groupby(['customer_id','country']).count()
# Out:
#                             invoice_no  invoice_date  year  month  day  hours  \
# customer_id country
# 12346       United Kingdom           1             1     1      1    1      1
# 12347       Iceland                182           182   182    182  182    182
# 12348       Finland                 31            31    31     31   31     31
# 12349       Italy                   73            73    73     73   73     73
# 12350       Norway                  17            17    17     17   17     17
# ...                                ...           ...   ...    ...  ...    ...
# 18280       United Kingdom          10            10    10     10   10     10
# 18281       United Kingdom           7             7     7      7    7      7
# 18282       United Kingdom          12            12    12     12   12     12
# 18283       United Kingdom         756           756   756    756  756    756
# 18287       United Kingdom          70            70    70     70   70     70
#
# ...

# %%
df_new.groupby(['customer_id','country'])['invoice_no'].count()
# Out:
# customer_id  country
# 12346        United Kingdom      1
# 12347        Iceland           182
# 12348        Finland            31
# 12349        Italy              73
# 12350        Norway             17
#                               ...
# 18280        United Kingdom     10
# 18281        United Kingdom      7
# 18282        United Kingdom     12
# 18283        United Kingdom    756
# 18287        United Kingdom     70
# Name: invoice_no, Length: 4347, dtype: int64

# %%
df_new.groupby(['customer_id','country'],as_index=False)['invoice_no'].count()
# Out:
#       customer_id         country  invoice_no
# 0           12346  United Kingdom           1
# 1           12347         Iceland         182
# 2           12348         Finland          31
# 3           12349           Italy          73
# 4           12350          Norway          17
# ...           ...             ...         ...
# 4342        18280  United Kingdom          10
# 4343        18281  United Kingdom           7
# 4344        18282  United Kingdom          12
# 4345        18283  United Kingdom         756
# 4346        18287  United Kingdom          70
#
# [4347 rows x 3 columns]

# %%
df_new.groupby(['customer_id','country'], as_index=False)['invoice_no'].count().head()
# Out:
#    customer_id         country  invoice_no
# 0        12346  United Kingdom           1
# 1        12347         Iceland         182
# 2        12348         Finland          31
# 3        12349           Italy          73
# 4        12350          Norway          17

# %% [markdown]
# #Data Visualization Libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
orders=df_new.groupby(['customer_id','country'],as_index=False)['invoice_no'].count()
orders
# Out:
#       customer_id         country  invoice_no
# 0           12346  United Kingdom           1
# 1           12347         Iceland         182
# 2           12348         Finland          31
# 3           12349           Italy          73
# 4           12350          Norway          17
# ...           ...             ...         ...
# 4342        18280  United Kingdom          10
# 4343        18281  United Kingdom           7
# 4344        18282  United Kingdom          12
# 4345        18283  United Kingdom         756
# 4346        18287  United Kingdom          70
#
# [4347 rows x 3 columns]

# %% [markdown]
# #Check Top 5 most number of orders

# %%
orders.sort_values('invoice_no',ascending=False).head()
# Out:
#       customer_id         country  invoice_no
# 4019        17841  United Kingdom        7847
# 1888        14911            EIRE        5677
# 1298        14096  United Kingdom        5111
# 334         12748  United Kingdom        4596
# 1670        14606  United Kingdom        2700

# %% [markdown]
# #Visualizing - Number of Orders for different Customers

# %%
orders=df_new.groupby(['customer_id','country'],as_index=False)['invoice_no'].count()
plt.subplots(figsize=(15,6))
plt.plot(orders.customer_id,orders.invoice_no)
plt.xlabel('Customer Id')
plt.ylabel('Number of Orders')
plt.title('Number of Orders for different Customers')
plt.show()

# %% [markdown]
# #How much money spent by each customer

# %%
df_new.groupby(['customer_id','country'])['amount_spent'].sum()
# Out:
# customer_id  country
# 12346        United Kingdom    77183.60
# 12347        Iceland            4310.00
# 12348        Finland            1797.24
# 12349        Italy              1757.55
# 12350        Norway              334.40
#                                  ...
# 18280        United Kingdom      180.60
# 18281        United Kingdom       80.82
# 18282        United Kingdom      178.05
# 18283        United Kingdom     2094.88
# 18287        United Kingdom     1837.28
# Name: amount_spent, Length: 4347, dtype: float64

# %%
money_spent=df_new.groupby(['customer_id','country'], as_index=False)['amount_spent'].sum()
money_spent
# Out:
#       customer_id         country  amount_spent
# 0           12346  United Kingdom      77183.60
# 1           12347         Iceland       4310.00
# 2           12348         Finland       1797.24
# 3           12349           Italy       1757.55
# 4           12350          Norway        334.40
# ...           ...             ...           ...
# 4342        18280  United Kingdom        180.60
# 4343        18281  United Kingdom         80.82
# 4344        18282  United Kingdom        178.05
# 4345        18283  United Kingdom       2094.88
# 4346        18287  United Kingdom       1837.28
#
# [4347 rows x 3 columns]

# %% [markdown]
# #Top 5 Customers who spent highest amount of money

# %%
money_spent.sort_values('amount_spent',ascending=False).head()
# Out:
#       customer_id         country  amount_spent
# 1698        14646     Netherlands     280206.02
# 4210        18102  United Kingdom     259657.30
# 3737        17450  United Kingdom     194550.79
# 3017        16446  United Kingdom     168472.50
# 1888        14911            EIRE     143825.06

# %% [markdown]
# #Top 10 Customers who spent highest amount of money

# %%
money_spent.sort_values('amount_spent',ascending=False).head(10)
# Out:
#       customer_id         country  amount_spent
# 1698        14646     Netherlands     280206.02
# 4210        18102  United Kingdom     259657.30
# 3737        17450  United Kingdom     194550.79
# 3017        16446  United Kingdom     168472.50
# 1888        14911            EIRE     143825.06
# 57          12415       Australia     124914.53
# 1342        14156            EIRE     117379.63
# 3780        17511  United Kingdom      91062.38
# 2711        16029  United Kingdom      81024.84
# 0           12346  United Kingdom      77183.60

# %% [markdown]
# #Visualizing - Money spent for different customers

# %%
money_spent=df_new.groupby(['customer_id','country'],as_index=False)['amount_spent'].count()
plt.subplots(figsize=(15,6))
plt.plot(money_spent.customer_id,money_spent.amount_spent)
plt.xlabel('Customer Id')
plt.ylabel('Money sepnt(Dollers)')
plt.title('Money sepnt for different Customers')
plt.show()

# %% [markdown]
# #Number of orders for different month

# %%
color=sns.color_palette()
sns.set_style('whitegrid')
plt.figure(figsize=(12,6))
sns.countplot(x='month',data=df_new,palette=color)
# Out:
# /tmp/ipython-input-1655231665.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='month',data=df_new,palette=color)
# /tmp/ipython-input-1655231665.py:4: UserWarning:
# The palette list has fewer values (10) than needed (12) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(x='month',data=df_new,palette=color)
# <Axes: xlabel='month', ylabel='count'>

# %%
df_new.head()
# Out:
#   invoice_no        invoice_date  year  month  day  hours stock_code  \
# 0     536365 2010-12-01 08:26:00  2010     12    3      8     85123A
# 1     536365 2010-12-01 08:26:00  2010     12    3      8      71053
# 2     536365 2010-12-01 08:26:00  2010     12    3      8     84406B
# 3     536365 2010-12-01 08:26:00  2010     12    3      8     84029G
# 4     536365 2010-12-01 08:26:00  2010     12    3      8     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    customer_id         country
# 0        17850  United Kingdom
# 1        17850  United Kingdom
# ...

# %%
df_new.groupby('invoice_no')

# %%
df_new.groupby('invoice_no')['year']

# %%
df_new.groupby('invoice_no')['year'].unique()
# Out:
# invoice_no
# 536365    [2010]
# 536366    [2010]
# 536367    [2010]
# 536368    [2010]
# 536369    [2010]
#            ...
# 581583    [2011]
# 581584    [2011]
# 581585    [2011]
# 581586    [2011]
# 581587    [2011]
# Name: year, Length: 18536, dtype: object

# %%
df_new.groupby('invoice_no')['year'].unique().value_counts()
# Out:
# year
# [2011]    17136
# [2010]     1400
# Name: count, dtype: int64

# %% [markdown]
# #How many orders(per day)?

# %%
df_new.groupby('invoice_no')

# %%
df_new.groupby('invoice_no')['day']

# %%
df_new.groupby('invoice_no')['day'].unique()
# Out:
# invoice_no
# 536365    [3]
# 536366    [3]
# 536367    [3]
# 536368    [3]
# 536369    [3]
#          ...
# 581583    [5]
# 581584    [5]
# 581585    [5]
# 581586    [5]
# 581587    [5]
# Name: day, Length: 18536, dtype: object

# %%
df_new.groupby('invoice_no')['day'].unique().value_counts()
# Out:
# day
# [4]    4033
# [3]    3455
# [2]    3185
# [1]    2863
# [5]    2831
# [7]    2169
# Name: count, dtype: int64

# %%
df_new.groupby('invoice_no')['day'].unique().value_counts().sort_index()
# Out:
# day
# [1]    2863
# [2]    3185
# [3]    3455
# [4]    4033
# [5]    2831
# [7]    2169
# Name: count, dtype: int64

# %% [markdown]
# #Day wise sales count/business

# %%
df_new.head()
# Out:
#   invoice_no        invoice_date  year  month  day  hours stock_code  \
# 0     536365 2010-12-01 08:26:00  2010     12    3      8     85123A
# 1     536365 2010-12-01 08:26:00  2010     12    3      8      71053
# 2     536365 2010-12-01 08:26:00  2010     12    3      8     84406B
# 3     536365 2010-12-01 08:26:00  2010     12    3      8     84029G
# 4     536365 2010-12-01 08:26:00  2010     12    3      8     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    customer_id         country
# 0        17850  United Kingdom
# 1        17850  United Kingdom
# ...

# %%
df_new.groupby('invoice_no')['day'].unique().value_counts().sort_index()
# Out:
# day
# [1]    2863
# [2]    3185
# [3]    3455
# [4]    4033
# [5]    2831
# [7]    2169
# Name: count, dtype: int64

# %% [markdown]
# #Lets visualize Day wise sales count/business

# %%
ax=df_new.groupby('invoice_no')['day'].unique().value_counts().sort_index().plot(kind='bar',color=color[0],figsize=(12,6))
ax.set_xlabel('Day')
ax.set_ylabel('Number of Orders')
ax.set_title('Day wise sales count/business')
# Out:
# Text(0.5, 1.0, 'Day wise sales count/business')

# %%
ax=df_new.groupby('invoice_no')['day'].unique().value_counts().sort_index().plot(kind='bar',color=color[0],figsize=(12,6))
ax.set_xlabel('Day')
ax.set_ylabel('Number of Orders')
ax.set_title('Day wise sales count/business')
d=('Mon','Tue','Wed','Thu','Fri','Sun') # Removed 'Sat'
ax.set_xticklabels(d,rotation='horizontal',fontsize=10)
# Out:
# [Text(0, 0, 'Mon'),
#  Text(1, 0, 'Tue'),
#  Text(2, 0, 'Wed'),
#  Text(3, 0, 'Thu'),
#  Text(4, 0, 'Fri'),
#  Text(5, 0, 'Sun')]

# %%
df_new.head()
# Out:
#   invoice_no        invoice_date  year  month  day  hours stock_code  \
# 0     536365 2010-12-01 08:26:00  2010     12    3      8     85123A
# 1     536365 2010-12-01 08:26:00  2010     12    3      8      71053
# 2     536365 2010-12-01 08:26:00  2010     12    3      8     84406B
# 3     536365 2010-12-01 08:26:00  2010     12    3      8     84029G
# 4     536365 2010-12-01 08:26:00  2010     12    3      8     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    customer_id         country
# 0        17850  United Kingdom
# 1        17850  United Kingdom
# ...

# %% [markdown]
# #Discover patterns for Unit Price

# %%
df_new.unit_price
# Out:
# 0         2.55
# 1         3.39
# 2         2.75
# 3         3.39
# 4         3.39
#           ...
# 541904    0.85
# 541905    2.10
# 541906    4.15
# 541907    4.15
# 541908    4.95
# Name: unit_price, Length: 397924, dtype: float64

# %%
df_new.unit_price.describe()
# Out:
# count    397924.000000
# mean          3.116174
# std          22.096788
# min           0.000000
# 25%           1.250000
# 50%           1.950000
# 75%           3.750000
# max        8142.750000
# Name: unit_price, dtype: float64

# %% [markdown]
# #Min value for product is zero, so there are some free products

# %%
#check the description of unit price
plt.subplots(figsize=(12,6))
sns.boxplot(df_new.unit_price)
plt.show()

# %% [markdown]
# #How many orders for each country?

# %%
df_new
# Out:
#        invoice_no        invoice_date  year  month  day  hours stock_code  \
# 0          536365 2010-12-01 08:26:00  2010     12    3      8     85123A
# 1          536365 2010-12-01 08:26:00  2010     12    3      8      71053
# 2          536365 2010-12-01 08:26:00  2010     12    3      8     84406B
# 3          536365 2010-12-01 08:26:00  2010     12    3      8     84029G
# 4          536365 2010-12-01 08:26:00  2010     12    3      8     84029E
# ...           ...                 ...   ...    ...  ...    ...        ...
# 541904     581587 2011-12-09 12:50:00  2011     12    5     12      22613
# 541905     581587 2011-12-09 12:50:00  2011     12    5     12      22899
# 541906     581587 2011-12-09 12:50:00  2011     12    5     12      23254
# 541907     581587 2011-12-09 12:50:00  2011     12    5     12      23255
# 541908     581587 2011-12-09 12:50:00  2011     12    5     12      22138
#
#                                 description  quantity  unit_price  \
# ...

# %%
df_new.groupby('country')

# %%
df_new.groupby('country')['invoice_no']

# %%
df_new.groupby('country')['invoice_no'].count()
# Out:
# country
# Australia                 1185
# Austria                    398
# Bahrain                     17
# Belgium                   2031
# Brazil                      32
# Canada                     151
# Channel Islands            748
# Cyprus                     614
# Czech Republic              25
# Denmark                    380
# EIRE                      7238
# European Community          60
# Finland                    685
# France                    8342
# Germany                   9042
# Greece                     145
# Iceland                    182
# Israel                     248
# Italy                      758
# Japan                      321
# Lebanon                     45
# Lithuania                   35
# Malta                      112
# Netherlands               2363
# Norway                    1072
# Poland                     330
# Portugal                  1462
# RSA                         58
# Saudi Arabia                 9
# Singapore                  222
# ...

# %%
df_new.groupby('country')['invoice_no'].count().sort_values()
# Out:
# country
# Saudi Arabia                 9
# Bahrain                     17
# Czech Republic              25
# Brazil                      32
# Lithuania                   35
# Lebanon                     45
# RSA                         58
# European Community          60
# United Arab Emirates        68
# Malta                      112
# Greece                     145
# Canada                     151
# USA                        179
# Iceland                    182
# Singapore                  222
# Unspecified                244
# Israel                     248
# Japan                      321
# Poland                     330
# Denmark                    380
# Austria                    398
# Sweden                     451
# Cyprus                     614
# Finland                    685
# Channel Islands            748
# Italy                      758
# Norway                    1072
# Australia                 1185
# Portugal                  1462
# Switzerland               1842
# ...

# %% [markdown]
# #How many orders for each country?

# %%
group_country=df_new.groupby('country')['invoice_no'].count().sort_values()
plt.subplots(figsize=(12,6))
group_country.plot(kind='bar',color=color[0])
plt.xlabel('Country')
plt.ylabel('Number of Orders')
plt.title('Number of Orders for different country')
plt.show()

# %%
group_country_orders = df_new.groupby('country')['invoice_no'].count().sort_values()
del group_country_orders['United Kingdom']

# plot number of unique customers in each country (with UK)
plt.subplots(figsize=(15,8))
group_country_orders.plot(kind = 'barh', fontsize=12, color=color[0])
plt.xlabel('Number of Orders', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Number of Orders for different Countries', fontsize=12)
plt.show()

# %% [markdown]
# #How much money spent by each country?

# %%
df_new
# Out:
#        invoice_no        invoice_date  year  month  day  hours stock_code  \
# 0          536365 2010-12-01 08:26:00  2010     12    3      8     85123A
# 1          536365 2010-12-01 08:26:00  2010     12    3      8      71053
# 2          536365 2010-12-01 08:26:00  2010     12    3      8     84406B
# 3          536365 2010-12-01 08:26:00  2010     12    3      8     84029G
# 4          536365 2010-12-01 08:26:00  2010     12    3      8     84029E
# ...           ...                 ...   ...    ...  ...    ...        ...
# 541904     581587 2011-12-09 12:50:00  2011     12    5     12      22613
# 541905     581587 2011-12-09 12:50:00  2011     12    5     12      22899
# 541906     581587 2011-12-09 12:50:00  2011     12    5     12      23254
# 541907     581587 2011-12-09 12:50:00  2011     12    5     12      23255
# 541908     581587 2011-12-09 12:50:00  2011     12    5     12      22138
#
#                                 description  quantity  unit_price  \
# ...

# %%
df_new.groupby('country')

# %%
df_new.groupby('country')['amount_spent']

# %%
df_new.groupby('country')['amount_spent'].sum()
# Out:
# country
# Australia                138521.310
# Austria                   10198.680
# Bahrain                     548.400
# Belgium                   41196.340
# Brazil                     1143.600
# Canada                     3666.380
# Channel Islands           20450.440
# Cyprus                    13590.380
# Czech Republic              826.740
# Denmark                   18955.340
# EIRE                     265545.900
# European Community         1300.250
# Finland                   22546.080
# France                   209024.050
# Germany                  228867.140
# Greece                     4760.520
# Iceland                    4310.000
# Israel                     7221.690
# Italy                     17483.240
# Japan                     37416.370
# Lebanon                    1693.880
# Lithuania                  1661.060
# Malta                      2725.590
# Netherlands              285446.340
# Norway                    36165.440
# Poland                     7334.650
# ...

# %%
df_new.groupby('country')['amount_spent'].sum().sort_values()
# Out:
# country
# Saudi Arabia                145.920
# Bahrain                     548.400
# Czech Republic              826.740
# RSA                        1002.310
# Brazil                     1143.600
# European Community         1300.250
# Lithuania                  1661.060
# Lebanon                    1693.880
# United Arab Emirates       1902.280
# Unspecified                2667.070
# Malta                      2725.590
# USA                        3580.390
# Canada                     3666.380
# Iceland                    4310.000
# Greece                     4760.520
# Israel                     7221.690
# Poland                     7334.650
# Austria                   10198.680
# Cyprus                    13590.380
# Italy                     17483.240
# Denmark                   18955.340
# Channel Islands           20450.440
# Singapore                 21279.290
# Finland                   22546.080
# Portugal                  33439.890
# Norway                    36165.440
# ...

# %% [markdown]
# #How much money spent by each country?

# %%
group_country_amount_spent = df_new.groupby('country')['amount_spent'].sum().sort_values()
# del group_country_orders['United Kingdom']

# plot total money spent by each country (with UK)
plt.subplots(figsize=(15,8))
group_country_amount_spent.plot(kind = 'barh', fontsize=12, color=color[0])
plt.xlabel('Money Spent (Dollar)', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Money Spent by different Countries', fontsize=12)
plt.show()

# %%
group_country_amount_spent = df_new.groupby('country')['amount_spent'].sum().sort_values()
del group_country_amount_spent['United Kingdom']

# plot total money spent by each country (with UK)
plt.subplots(figsize=(15,8))
group_country_amount_spent.plot(kind = 'barh', fontsize=12, color=color[0])
plt.xlabel('Money Spent (Dollar)', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Money Spent by different Countries', fontsize=12)
plt.show()
